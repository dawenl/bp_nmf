# %%
""" Toy example for BP-NMF 
"""
import time

import bp_nmf
from bp_utils import *
import librosa

# %%
n_fft = 512
hop_length = 256
X = load_data('data/demo.mp3', n_fft, hop_length, sr=22050)
K = 512

# %%
threshold = 0.0001
maxiter = 100
objs = []
old_obj = -np.inf
bnmf = bp_nmf.LVI_BP_NMF(X, K=K, seed=357)
# Out:
# Using fixed seed 357
# bp_nmf.py:328: RuntimeWarning: overflow encountered in exp
#   return (np.exp(mu + 1. / (2 * r)), np.exp(2 * mu + 2. / r))

# %%
for i in xrange(maxiter):
    start_t = time.time()
    bnmf.update(verbose=True, disp=1)
    t = time.time() - start_t
    objs.append(bnmf.obj)
    improvement = (bnmf.obj - old_obj) / abs(old_obj)
    old_obj = bnmf.obj
    print 'Iteration: {}, good K: {}, time: {:.2f}, obj: {:.2f} (improvement: {:.4f})'.format(i, bnmf.good_k.size, t, bnmf.obj, improvement)
    if improvement < threshold:
        break
# Out:
# Updating DZS...
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# bp_nmf.py:256: RuntimeWarning: overflow encountered in exp
#   self.p_z[k] = 1. / (1 + np.exp(p0 - p1))
# -c:6: RuntimeWarning: invalid value encountered in double_scalars
# Updating pi and gamma...
# Iteration: 0, good K: 89, time: 38.21, obj: -105065312.89 (improvement: nan)
# Updating DZS...
# .
# ..
# ..
# Updating pi and gamma...
# Iteration: 1, good K: 65, time: 2.44, obj: -40000294.83 (improvement: 0.6193)
# Updating DZS...
# .
# ..
# .
# Updating pi and gamma...
# Iteration: 2, good K: 24, time: 1.43, obj: -39949241.43 (improvement: 0.0013)
# Updating DZS...
# .
# .
# Updating pi and gamma...
# Iteration: 3, good K: 15, time: 0.93, obj: -39931496.52 (improvement: 0.0004)
# Updating DZS...
# .
# .
# Updating pi and gamma...
# Iteration: 4, good K: 10, time: 1.09, obj: -39906435.81 (improvement: 0.0006)
# Updating DZS...
# .
# Updating pi and gamma...
# Iteration: 5, good K: 7, time: 1.15, obj: -39875452.04 (improvement: 0.0008)
# Updating DZS...
# .
# Updating pi and gamma...
# Iteration: 6, good K: 7, time: 1.57, obj: -39856280.47 (improvement: 0.0005)
# Updating DZS...
# .
# Updating pi and gamma...
# Iteration: 7, good K: 7, time: 1.41, obj: -39849361.45 (improvement: 0.0002)
# Updating DZS...
# .
# Updating pi and gamma...
# Iteration: 8, good K: 7, time: 1.18, obj: -39847233.31 (improvement: 0.0001)

# %%
print 'sigma_error = {}'.format(sqrt(1./bnmf.Eg))
plot(objs[1:])
pass
# Out:
# sigma_error = 0.908511304994

# %%
good_k = bnmf.good_k

idx = flipud(argsort(bnmf.Epi[good_k]))
# normalize the dictionary so that each component has maximum 1
ED = bnmf.ED[:,good_k[idx]]
ED /= np.max(ED, axis=0, keepdims=True)
ES = bnmf.ES[good_k[idx],:]
ES *= np.max(bnmf.ED[:,good_k[idx]], axis=0, keepdims=True).T
EZ = around(bnmf.EZ[good_k[idx],:])

Xres = dot(ED, ES * EZ)
res = X - Xres

## Original v.s. Reconstruction
figure(1)
gsubplot(args=({'D':logspec(X), 'T':'Original Spectrogram'}, 
               {'D':logspec(Xres), 'T':'Reconstruction '} , 
               {'D':res, 'T':'Reconstruction Error'}), cmap=cm.hot_r)
## Plot decomposition
figure(2)
gsubplot(args=({'D':logspec(ED), 'T':'ED'}, 
               {'D':EZ, 'T':'EZ'}, 
               {'D':logspec(EZ*ES), 'T':'ES*EZ'}), cmap=cm.hot_r)
figure(3)
plot(flipud(sort(bnmf.Epi[good_k])), '-o')
title('Expected membership prior Pi')
pass

# %%
fig(figsize=(16, 10))
num = len(good_k)
for i in xrange(0, 2*num, 2):
    subplot(num, 2, i+1)
    plot(10*log10(ED[:, i/2]))
    subplot(num, 2, i+2)
    plot((EZ * ES)[i/2,:])
tight_layout()
